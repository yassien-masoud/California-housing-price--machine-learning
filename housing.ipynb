# %%
import pandas as pd

# %%
#load data
train=pd.read_csv("train.csv")
test=pd.read_csv("test.csv")
test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
data=pd.concat([train,test])
data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
X=data.iloc[:,:80]
y=data.SalePrice

# %%
quant=[i for i in data.columns if data.dtypes[i] != 'object']
quant.remove('SalePrice')
quant.remove('Id')
quality=[i for i in data.columns if data.dtypes[i] == 'object']

# %%
data[quant]
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0             60         65.0     8450            7            5       2003
# 1             20         80.0     9600            6            8       1976
# 2             60         68.0    11250            7            5       2001
# 3             70         60.0     9550            7            5       1915
# 4             60         84.0    14260            8            5       2000
# ...          ...          ...      ...          ...          ...        ...
# 1454         160         21.0     1936            4            7       1970
# 1455         160         21.0     1894            4            5       1970
# 1456          20        160.0    20000            5            7       1960
# 1457          85         62.0    10441            5            5       1992
# 1458          60         74.0     9627            7            5       1993
#
# ...

# %%
data[quality]
# Out:
#      MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2          RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4          RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
# ...       ...    ...   ...      ...         ...       ...       ...       ...
# 1454       RM   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1455       RM   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1456       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Mod
#
# ...

# %% [markdown]
# ### Numeric Missing Values

# %%
# find the missing values

quant_data_missing=data[quant].isnull().sum()
quant_data_missing=pd.DataFrame(data_quant_missing[data_quant_missing>0])
quant_data_missing
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-c5720246f8bb> in <module>
#       2
#       3 quant_data_missing=data[quant].isnull().sum()
# ----> 4 quant_data_missing=pd.DataFrame(data_quant_missing[data_quant_missing>0])
#       5 quant_data_missing
#
# NameError: name 'data_quant_missing' is not defined

# %%
# Impute missing values 
from sklearn.impute import SimpleImputer 
my_imputer=SimpleImputer()
impute_numric=pd.DataFrame(my_imputer.fit_transform(data[quant]))
impute_numric.columns=data[quant].columns
impute_numric
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0           60.0         65.0   8450.0          7.0          5.0     2003.0
# 1           20.0         80.0   9600.0          6.0          8.0     1976.0
# 2           60.0         68.0  11250.0          7.0          5.0     2001.0
# 3           70.0         60.0   9550.0          7.0          5.0     1915.0
# 4           60.0         84.0  14260.0          8.0          5.0     2000.0
# ...          ...          ...      ...          ...          ...        ...
# 2914       160.0         21.0   1936.0          4.0          7.0     1970.0
# 2915       160.0         21.0   1894.0          4.0          5.0     1970.0
# 2916        20.0        160.0  20000.0          5.0          7.0     1960.0
# 2917        85.0         62.0  10441.0          5.0          5.0     1992.0
# 2918        60.0         74.0   9627.0          7.0          5.0     1993.0
#
# ...

# %% [markdown]
# ### Categorical Missing Values

# %%
# finding the miss values

qaulity_missing_data= data[quality].isnull().sum() 
qaulity_missing_data= pd.DataFrame(qaulity_missing_data[qaulity_missing_data >0].sort_values(ascending=False))
qaulity_missing_data
# Out:
#                  0
# PoolQC        2909
# MiscFeature   2814
# Alley         2721
# Fence         2348
# FireplaceQu   1420
# GarageCond     159
# GarageQual     159
# GarageFinish   159
# GarageType     157
# BsmtExposure    82
# BsmtCond        82
# BsmtQual        81
# BsmtFinType2    80
# BsmtFinType1    79
# MasVnrType      24
# MSZoning         4
# Functional       2
# Utilities        2
# Exterior1st      1
# SaleType         1
# Exterior2nd      1
# KitchenQual      1
# Electrical       1

# %%
data[quality].isnull().sum().sum()
# Out:
# 13287

# %%
#filling the massing values
my_impute= SimpleImputer(strategy="most_frequent")
impute_Category= pd.DataFrame(my_impute.fit_transform(data[quality]))
impute_Category.columns= data[quality].columns
impute_Category
# Out:
# 0

# %%
all_data=pd.concat([impute_Category, impute_numric])
all_data
# Out:
#      MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave  Grvl      Reg         Lvl    AllPub       FR2       Gtl
# 2          RL   Pave  Grvl      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   Pave  Grvl      IR1         Lvl    AllPub    Corner       Gtl
# 4          RL   Pave  Grvl      IR1         Lvl    AllPub       FR2       Gtl
# ...       ...    ...   ...      ...         ...       ...       ...       ...
# 2914      NaN    NaN   NaN      NaN         NaN       NaN       NaN       NaN
# 2915      NaN    NaN   NaN      NaN         NaN       NaN       NaN       NaN
# 2916      NaN    NaN   NaN      NaN         NaN       NaN       NaN       NaN
# 2917      NaN    NaN   NaN      NaN         NaN       NaN       NaN       NaN
# 2918      NaN    NaN   NaN      NaN         NaN       NaN       NaN       NaN
#
# ...

# %% [markdown]
# ### correlation

# %%
import matplotlib.pyplot as plt
import seaborn as sb
correlation=all_data.corr()
f, ax =plt.subplots(figsize=(30,40))
sb.heatmap(correlation,annot=True)
# Out:
# <AxesSubplot:>
